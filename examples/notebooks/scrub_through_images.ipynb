# %%
import sys
sys.path.append("../../")

import radvis as rv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
IMAGE_PATH = "../images/sub-A00028185_ses-NFB3_T1w.nii.gz"

# Load the RadImage
image = rv.load_image(IMAGE_PATH)

# %%
slicer = rv.RadSlicer(image, 0, show_slider=True)

red_mask = np.zeros_like(image.image_data) 
red_mask[5:100, 5:100, 5:100] = 1

blue_mask = np.zeros_like(image.image_data)
blue_mask[70:150, 70:150, 70:150] = 1

slicer.add_mask(red_mask, color="red")
slicer.add_mask(blue_mask, color="blue")

# %%
slicer_group = rv.RadSlicerGroup([slicer, slicer.copy()], 1, 2)
slicer_group.display()
# Out:
# interactive(children=(IntSlider(value=0, description='Axis: 0: Slice', max=255), Output()), _dom_classes=('wid…
# interactive(children=(IntSlider(value=0, description='Axis: 0: Slice', max=255), Output()), _dom_classes=('wid…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
