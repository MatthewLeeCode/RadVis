# %%
import sys
sys.path.append("../")

import matplotlib.pyplot as plt
# %matplotlib widget
import radvis as rv

# %%
IMAGE_PATH = "images/test_nifti.nii.gz"

# %%
image = rv.load_image(IMAGE_PATH)

# %%
slicer = rv.RadSlicer(image, 2)
slicer2 = rv.RadSlicer(image, 1)
slicer.display()
slicer2.display()
# Out:
# interactive(children=(IntSlider(value=0, description='Axis: 2: Slice', max=255), Output()), _dom_classes=('wid…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(IntSlider(value=0, description='Axis: 1: Slice', max=255), Output()), _dom_classes=('wid…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
