# %%
import sys
sys.path.append("../")

import matplotlib.pyplot as plt
# %matplotlib widget
import radvis as rv

# %%
IMAGE_PATH = "images/test_nifti.nii.gz"

# %%
image = rv.load_image(IMAGE_PATH)

# %%
slicer = rv.RadSlicer(image)
slicer.display()
# Out:
# interactive(children=(IntSlider(value=0, description='val', max=191), Output()), _dom_classes=('widget-interac…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
